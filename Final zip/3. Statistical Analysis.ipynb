# %% [markdown]
# ## Importing libraries

# %%
import os
import pandas as pd
import numpy as np
from itertools import combinations
from scipy.stats import chi2_contingency
from scipy.stats import fisher_exact
from scipy.stats import kruskal, mannwhitneyu

# %% [markdown]
# ## Importing data

# %%
current_directory = os.getcwd()
file_name = 'Clustered_df.csv'
data = pd.read_csv(os.path.join(current_directory, file_name), index_col="Unnamed: 0")
print(data.columns)
# Out:
# Index(['Age', 'Education', 'Affective Symptoms', 'Rumination',
#        'Behavioural Symptoms', 'Anxiety Personal Impact',
#        'Attribution Skepticism', 'Impact Skepticism', 'Trend Skepticism',
#        'Response Skepticism', 'Male', 'Female', 'Non-binary', 'Single',
#        'Married', 'Divorced', 'Widowed', 'Separated', 'Income', 'Cluster'],
#       dtype='object')

# %% [markdown]
# # Statistical Analysis for attributes comparison

# %% [markdown]
# ## CATEGORICAL VARIABLES (Chi-Squared and Fisher's Exact Test)

# %%
df_categorical = data
columns_to_drop = ['Age', 'Income']
df_categorical = df_categorical.drop(columns=columns_to_drop)

print(df_categorical.columns)
# Out:
# Index(['Education', 'Affective Symptoms', 'Rumination', 'Behavioural Symptoms',
#        'Anxiety Personal Impact', 'Attribution Skepticism',
#        'Impact Skepticism', 'Trend Skepticism', 'Response Skepticism', 'Male',
#        'Female', 'Non-binary', 'Single', 'Married', 'Divorced', 'Widowed',
#        'Separated', 'Cluster'],
#       dtype='object')

# %% [markdown]
# ### Computation of p-values for each feature, comparing the three groups together (1 test per feature)

# %%
cluster_colonna = 'Cluster'

# Itera su tutte le colonne tranne la colonna 'Cluster'
for attributo_selezionato in df_categorical.columns[df_categorical.columns != cluster_colonna]:
    # Calcola la tabella di contingenza per l'attributo corrente
    contingency_table = pd.crosstab(df_categorical[attributo_selezionato], df_categorical[cluster_colonna])
    
    # Stampa il risultato
    print(f"\nTabella di contingenza per l'attributo {attributo_selezionato}:\n{contingency_table}")
    
    all_values_above_5 = np.all(contingency_table >= 5)

    if all_values_above_5:  # Apply Chi-squared
        print(f"\nFor the feature {attributo_selezionato}, all expected frequencies are at least 5. I can perform Chi-Squared test")
        # Perform Chi-squared test
        chi2_stat, p_value, _, _ = chi2_contingency(contingency_table)

        # Results:
        print(f"Feature: {attributo_selezionato}")
        print(f"Chi-square Statistic: {chi2_stat}")
        print(f"P-Value: {p_value}")
        
    else: 
        print(f"\nFor the feature {attributo_selezionato}, some expected frequencies are below 5. Consider alternative methods.")

        print("I have to perform Fisher's Exact Test for non binary features.")

        # I performed Fisher's Exact Test for non binary features in R and i got the following results:
        # See the "R code (groups together).r"
        results_fisher_together = [
            {"Test": "Education", "p_value": 0.0004997501},
            {"Test": "Affective Symptoms", "p_value": 0.0004997501},
            {"Test": "Rumination", "p_value": 0.0004997501},
            {"Test": "Behavioural Symptoms", "p_value": 0.0004997501},
            {"Test": "Anxiety Personal Impact", "p_value": 0.0004997501},
            {"Test": "Attribution Skepticism", "p_value": 0.0004997501},
            {"Test": "Impact Skepticism", "p_value": 0.0004997501},
            {"Test": "Trend Skepticism", "p_value": 0.0004997501},
            {"Test": "Response Skepticism", "p_value": 0.9375312},
            {"Test": "Single", "p_value": 0.0004997501},
            {"Test": "Widowed", "p_value": 0.1454273},
            {"Test": "Separated", "p_value": 0.0004997501},
            ]

         # Create a DataFrame with named rows
        results_fisher_together_df = pd.DataFrame(results_fisher_together)
        results_fisher_together_df.set_index("Test", inplace=True)
        
        feature_val = str(attributo_selezionato)

        # Extract the p-value for the specified feature
        p_value_together = results_fisher_together_df.loc[feature_val, 'p_value']

        print(f"Feature: {attributo_selezionato}")
        print(f"Fisher P value: {p_value_together}")
# Out:
# Tabella di contingenza per l'attributo Education:
# Cluster     1   2   3
# Education
# 5.000000    0   8   0
# 8.000000    0  24  12
# 13.000000  11  14  31
# 14.100629   1   0   0
# 18.000000  18   7   9
# 22.000000  15   0   2
# 25.000000   8   0   0
#
# For the feature Education, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Education
# Fisher P value: 0.0004997501
#
# Tabella di contingenza per l'attributo Affective Symptoms:
# Cluster              1   2   3
# Affective Symptoms
# 0.000000             3   0   0
# 0.250000             4   0   0
# 0.500000             8   0   0
# 0.750000            11   0   1
# 1.000000             5   0   4
# 1.250000             6   0   5
# 1.333333             0   0   1
# 1.500000             5   0   6
# 1.666667             1   0   0
# 1.750000             5   1   8
# 2.000000             3   0  10
# 2.250000             1   5   6
# 2.500000             0  15   1
# 2.666667             0   0   1
# 2.750000             0   9   9
# 3.000000             1  23   2
#
# For the feature Affective Symptoms, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Affective Symptoms
# Fisher P value: 0.0004997501
#
# Tabella di contingenza per l'attributo Rumination:
# Cluster     1   2   3
# Rumination
# 0.000000    6   0   1
# 0.333333    9   0   0
# 0.666667    7   0   1
# 1.000000    7   0   2
# 1.333333    9   0   6
# 1.666667    8   1   5
# 2.000000    6   2  16
# 2.333333    0  13  14
# 2.666667    0  10   3
# 3.000000    1  27   6
#
# For the feature Rumination, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Rumination
# Fisher P value: 0.0004997501
#
# Tabella di contingenza per l'attributo Behavioural Symptoms:
# Cluster                1   2   3
# Behavioural Symptoms
# 0.000000               5   0   2
# 0.333333               8   0   0
# 0.500000               1   0   0
# 0.666667               7   0   0
# 1.000000               7   0   4
# 1.333333               7   1  11
# 1.666667              10   3   6
# 2.000000               7   0  17
# 2.333333               1   8   3
# 2.666667               0   5   5
# 3.000000               0  36   6
#
# For the feature Behavioural Symptoms, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Behavioural Symptoms
# Fisher P value: 0.0004997501
#
# Tabella di contingenza per l'attributo Anxiety Personal Impact:
# Cluster                   1   2   3
# Anxiety Personal Impact
# 0.000000                  5   0   0
# 0.333333                  5   0   0
# 0.500000                  1   0   0
# 0.666667                  7   0   1
# 1.000000                 10   0   4
# 1.333333                  7   0   6
# 1.500000                  1   0   0
# 1.666667                  6   2   8
# 2.000000                  6   2  15
# 2.333333                  5   9  10
# 2.666667                  0   8   3
# 3.000000                  0  32   7
#
# For the feature Anxiety Personal Impact, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Anxiety Personal Impact
# Fisher P value: 0.0004997501
#
# Tabella di contingenza per l'attributo Attribution Skepticism:
# Cluster                  1   2   3
# Attribution Skepticism
# 0.000000                 6   0   0
# 0.333333                12   0   0
# 0.666667                12   0   0
# 1.000000                14   0   0
# 1.333333                 8   0   0
# 1.666667                 1   0  14
# 2.000000                 0   0   8
# 2.333333                 0   0  14
# 2.500000                 0   1   1
# 2.666667                 0   0  17
# 3.000000                 0  18   0
# 3.333333                 0  11   0
# 3.666667                 0   9   0
# 4.000000                 0  14   0
#
# For the feature Attribution Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Attribution Skepticism
# Fisher P value: 0.0004997501
#
# Tabella di contingenza per l'attributo Impact Skepticism:
# Cluster             1   2   3
# Impact Skepticism
# 0.000000           10   0  10
# 0.333333           14   0  16
# 0.500000            0   0   1
# 0.666667            7   0  12
# 1.000000           12   0   4
# 1.333333           10   0  11
# 3.000000            0  21   0
# 3.333333            0  15   0
# 3.666667            0   4   0
# 4.000000            0  12   0
# 5.000000            0   1   0
#
# For the feature Impact Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Impact Skepticism
# Fisher P value: 0.0004997501
#
# Tabella di contingenza per l'attributo Trend Skepticism:
# Cluster            1   2   3
# Trend Skepticism
# 0.000000           8   0   0
# 0.333333           5   0   0
# 0.500000           1   0   0
# 0.666667           9   0   0
# 1.000000          13   0   0
# 1.333333          16   0   0
# 1.666667           1   0  14
# 2.000000           0   0  18
# 2.333333           0   0  13
# 2.666667           0   0   9
# 3.000000           0  12   0
# 3.333333           0  16   0
# 3.666667           0   9   0
# 4.000000           0  15   0
# 5.000000           0   1   0
#
# For the feature Trend Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Trend Skepticism
# Fisher P value: 0.0004997501
#
# Tabella di contingenza per l'attributo Response Skepticism:
# Cluster               1   2   3
# Response Skepticism
# 0.000000              0   0   1
# 0.500000              0   1   0
# 1.666667             13  16  15
# 2.000000             12  11  11
# 2.333333             13  16  15
# 2.666667             14   9  12
# 3.000000              1   0   0
#
# For the feature Response Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Response Skepticism
# Fisher P value: 0.9375312
#
# Tabella di contingenza per l'attributo Male:
# Cluster   1   2   3
# Male
# False    42  44  38
# True     11   9  16
#
# For the feature Male, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Male
# Chi-square Statistic: 2.592467357463638
# P-Value: 0.27356017070708016
#
# Tabella di contingenza per l'attributo Female:
# Cluster   1   2   3
# Female
# False    37  36  47
# True     16  17   7
#
# For the feature Female, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Female
# Chi-square Statistic: 6.348940135103657
# P-Value: 0.04181625800633923
#
# Tabella di contingenza per l'attributo Non-binary:
# Cluster      1   2   3
# Non-binary
# False       42  42  39
# True        11  11  15
#
# For the feature Non-binary, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Non-binary
# Chi-square Statistic: 0.9925802470671315
# P-Value: 0.6087849925959621
#
# Tabella di contingenza per l'attributo Single:
# Cluster   1   2   3
# Single
# False    25  53  49
# True     28   0   5
#
# For the feature Single, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Single
# Fisher P value: 0.0004997501
#
# Tabella di contingenza per l'attributo Married:
# Cluster   1   2   3
# Married
# False    41  28  19
# True     12  25  35
#
# For the feature Married, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Married
# Chi-square Statistic: 19.372198575552876
# P-Value: 6.214132771127725e-05
#
# Tabella di contingenza per l'attributo Divorced:
# Cluster    1   2   3
# Divorced
# False     46  40  48
# True       7  13   6
#
# For the feature Divorced, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Divorced
# Chi-square Statistic: 4.077146921416141
# P-Value: 0.13021433431165458
#
# Tabella di contingenza per l'attributo Widowed:
# Cluster   1   2   3
# Widowed
# False    53  49  50
# True      0   4   4
#
# For the feature Widowed, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Widowed
# Fisher P value: 0.1454273
#
# Tabella di contingenza per l'attributo Separated:
# Cluster     1   2   3
# Separated
# False      53  44  54
# True        0   9   0
#
# For the feature Separated, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Separated
# Fisher P value: 0.0004997501

# %% [markdown]
# ### Computation of p-values for each feature, comparing the three groups in pairs (3 test per feature)

# %%
# List of all categorical variables in the DataFrame
categorical_variables = df_categorical.columns.tolist()
cluster_colonna = 'Cluster'

# Significance level after Bonferroni correction
alpha = 0.05
alpha_adjusted = alpha / 3
count_dict = {variable: 0 for variable in categorical_variables}

for feature in df_categorical.columns[df_categorical.columns != cluster_colonna]:
    # Create a contingency table
    contingency_table = pd.crosstab(df_categorical[feature], df_categorical[cluster_colonna])

    # Iterate over all possible pairs of clusters
    clusters = df_categorical[cluster_colonna].unique()
    for i in range(len(clusters)):
        for j in range(i + 1, len(clusters)):
            # Create a contingency table for the pair of clusters
            subset_table = contingency_table[[clusters[i], clusters[j]]]
            print (f"\n {subset_table}")
            # Check if all expected frequencies are above 5
            all_values_above_5 = np.all(subset_table >= 5)

            if all_values_above_5:  # Apply Chi-square
                print(f"\nFor the feature {feature}, all expected frequencies are at least 5. I can perform Chi-Squared test")
                # Perform Chi-square test
                chi2_stat, p_value, _, _ = chi2_contingency(subset_table)

                # Results:
                print(f"Feature: {feature}, Cluster Pair: {clusters[i]} vs {clusters[j]}")
                print(f"Chi-square Statistic: {chi2_stat}")
                print(f"P-Value: {p_value}")
                print(f"Adjusted alpha with Bonferroni: {alpha_adjusted}")

                # Check if the result is statistically significant after Bonferroni correction
                if p_value < alpha_adjusted:
                    print(f"The clusters {clusters[i]} and {clusters[j]} are statistically different regarding the feature {feature}.")
                else:
                    print(f"The clusters {clusters[i]} and {clusters[j]} are NOT statistically different regarding the feature {feature}.")
                    count_dict[feature] += 1


            else: 
                print(f"\nFor the feature {feature}, some expected frequencies are below 5. Consider alternative methods.")
                
                if df_categorical[feature].nunique() < 3: # Apply Fisher
                    print("I can perform Fisher's Exact Test.")
                    # Perform Fisher’s Exact Test
                    odds_ratio, p_value = fisher_exact(subset_table)

                    # Results:
                    print(f"Feature: {feature}")
                    print(f"Fisher Odds Ratio: {odds_ratio}, p-value: {p_value}")
                    print(f"Adjusted alpha with Bonferroni: {alpha_adjusted}")

                    # Check if the result is statistically significant after Bonferroni correction
                    if p_value < alpha_adjusted:
                        print(f"The clusters {clusters[i]} and {clusters[j]} are statistically different regarding the feature {feature}.")
                    else:
                        print(f"The clusters {clusters[i]} and {clusters[j]} are NOT statistically different regarding the feature {feature}.")
                        count_dict[feature] += 1


                else:
                    print("I have to perform Fisher's Exact Test for non binary features.")

                    # I performed Fisher's Exact Test for non binary features in R and i got the following results:
                    # See the "R code (groups paired).r"
                    results_fisher = [
                        {"Test": "Education", "i":"2", "j":"1", "p_value": 0.0004997501},
                        {"Test": "Education", "i":"2", "j":"3","p_value": 0.0004997501},
                        {"Test": "Education", "i":"1", "j":"3","p_value": 0.0004997501},
                        {"Test": "Affective Symptoms", "i":"2", "j":"1","p_value": 0.0004997501},
                        {"Test": "Affective Symptoms", "i":"2", "j":"3","p_value": 0.0004997501},
                        {"Test": "Affective Symptoms", "i":"1", "j":"3","p_value": 0.0004997501},
                        {"Test": "Rumination", "i":"2", "j":"1","p_value": 0.0004997501},
                        {"Test": "Rumination", "i":"2", "j":"3","p_value": 0.0004997501},
                        {"Test": "Rumination", "i":"1", "j":"3","p_value": 0.0004997501},
                        {"Test": "Behavioural Symptoms", "i":"2", "j":"1","p_value": 0.0004997501},
                        {"Test": "Behavioural Symptoms", "i":"2", "j":"3","p_value": 0.0004997501},
                        {"Test": "Behavioural Symptoms", "i":"1", "j":"3","p_value": 0.0004997501},
                        {"Test": "Anxiety Personal Impact", "i":"2", "j":"1","p_value": 0.0004997501},
                        {"Test": "Anxiety Personal Impact", "i":"2", "j":"3","p_value": 0.0004997501},
                        {"Test": "Anxiety Personal Impact", "i":"1", "j":"3","p_value": 0.0004997501},
                        {"Test": "Attribution Skepticism", "i":"2", "j":"1","p_value": 0.0004997501},
                        {"Test": "Attribution Skepticism", "i":"2", "j":"3","p_value": 0.0004997501},
                        {"Test": "Attribution Skepticism", "i":"1", "j":"3","p_value": 0.0004997501},
                        {"Test": "Impact Skepticism", "i":"2", "j":"1","p_value": 0.0004997501},
                        {"Test": "Impact Skepticism", "i":"2", "j":"3","p_value": 0.0004997501},
                        {"Test": "Impact Skepticism", "i":"1", "j":"3","p_value": 0.2618691},
                        {"Test": "Trend Skepticism", "i":"2", "j":"1","p_value": 0.0004997501},
                        {"Test": "Trend Skepticism", "i":"2", "j":"3","p_value": 0.0004997501},
                        {"Test": "Trend Skepticism", "i":"1", "j":"3","p_value": 0.0004997501},
                        {"Test": "Response Skepticism", "i":"2", "j":"1","p_value": 0.6311844},
                        {"Test": "Response Skepticism", "i":"2", "j":"3","p_value": 0.934033},
                        {"Test": "Response Skepticism", "i":"1", "j":"3","p_value": 0.941029}
                    ]

                    # Create a DataFrame with named rows
                    results_fisher_df = pd.DataFrame(results_fisher)
                    results_fisher_df.set_index("Test", inplace=True)
                    
                    i_value = str(clusters[i])
                    j_value = str(clusters[j])
                    feature_value = str(feature)

                    # Filter the DataFrame based on conditions
                    filtered_df = results_fisher_df[(results_fisher_df['i'] == i_value) & (results_fisher_df['j'] == j_value)]
                    # Extract the p-value for the specified feature
                    p_value_to_compare = filtered_df.loc[feature_value, 'p_value']

                    print(f"Feature: {feature}")
                    print(f"Fisher P value: {p_value_to_compare}")
                    print(f"Adjusted alpha with Bonferroni: {alpha_adjusted}")

                    if p_value_to_compare < alpha_adjusted:
                        print(f"The clusters {clusters[i]} and {clusters[j]} are statistically different regarding the feature {feature}.")
                    else:
                        print(f"The clusters {clusters[i]} and {clusters[j]} are NOT statistically different regarding the feature {feature}.")
                        count_dict[feature] += 1
# Out:
#  Cluster     2   1
# Education
# 5.000000    8   0
# 8.000000   24   0
# 13.000000  14  11
# 14.100629   0   1
# 18.000000   7  18
# 22.000000   0  15
# 25.000000   0   8
#
# For the feature Education, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Education
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are statistically different regarding the feature Education.
#
#  Cluster     2   3
# Education
# 5.000000    8   0
# 8.000000   24  12
# 13.000000  14  31
# 14.100629   0   0
# 18.000000   7   9
# 22.000000   0   2
# 25.000000   0   0
#
# For the feature Education, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Education
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are statistically different regarding the feature Education.
#
#  Cluster     1   3
# Education
# 5.000000    0   0
# 8.000000    0  12
# 13.000000  11  31
# 14.100629   1   0
# 18.000000  18   9
# 22.000000  15   2
# 25.000000   8   0
#
# For the feature Education, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Education
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are statistically different regarding the feature Education.
#
#  Cluster              2   1
# Affective Symptoms
# 0.000000             0   3
# 0.250000             0   4
# 0.500000             0   8
# 0.750000             0  11
# 1.000000             0   5
# 1.250000             0   6
# 1.333333             0   0
# 1.500000             0   5
# 1.666667             0   1
# 1.750000             1   5
# 2.000000             0   3
# 2.250000             5   1
# 2.500000            15   0
# 2.666667             0   0
# 2.750000             9   0
# 3.000000            23   1
#
# For the feature Affective Symptoms, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Affective Symptoms
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are statistically different regarding the feature Affective Symptoms.
#
#  Cluster              2   3
# Affective Symptoms
# 0.000000             0   0
# 0.250000             0   0
# 0.500000             0   0
# 0.750000             0   1
# 1.000000             0   4
# 1.250000             0   5
# 1.333333             0   1
# 1.500000             0   6
# 1.666667             0   0
# 1.750000             1   8
# 2.000000             0  10
# 2.250000             5   6
# 2.500000            15   1
# 2.666667             0   1
# 2.750000             9   9
# 3.000000            23   2
#
# For the feature Affective Symptoms, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Affective Symptoms
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are statistically different regarding the feature Affective Symptoms.
#
#  Cluster              1   3
# Affective Symptoms
# 0.000000             3   0
# 0.250000             4   0
# 0.500000             8   0
# 0.750000            11   1
# 1.000000             5   4
# 1.250000             6   5
# 1.333333             0   1
# 1.500000             5   6
# 1.666667             1   0
# 1.750000             5   8
# 2.000000             3  10
# 2.250000             1   6
# 2.500000             0   1
# 2.666667             0   1
# 2.750000             0   9
# 3.000000             1   2
#
# For the feature Affective Symptoms, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Affective Symptoms
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are statistically different regarding the feature Affective Symptoms.
#
#  Cluster      2  1
# Rumination
# 0.000000     0  6
# 0.333333     0  9
# 0.666667     0  7
# 1.000000     0  7
# 1.333333     0  9
# 1.666667     1  8
# 2.000000     2  6
# 2.333333    13  0
# 2.666667    10  0
# 3.000000    27  1
#
# For the feature Rumination, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Rumination
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are statistically different regarding the feature Rumination.
#
#  Cluster      2   3
# Rumination
# 0.000000     0   1
# 0.333333     0   0
# 0.666667     0   1
# 1.000000     0   2
# 1.333333     0   6
# 1.666667     1   5
# 2.000000     2  16
# 2.333333    13  14
# 2.666667    10   3
# 3.000000    27   6
#
# For the feature Rumination, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Rumination
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are statistically different regarding the feature Rumination.
#
#  Cluster     1   3
# Rumination
# 0.000000    6   1
# 0.333333    9   0
# 0.666667    7   1
# 1.000000    7   2
# 1.333333    9   6
# 1.666667    8   5
# 2.000000    6  16
# 2.333333    0  14
# 2.666667    0   3
# 3.000000    1   6
#
# For the feature Rumination, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Rumination
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are statistically different regarding the feature Rumination.
#  Cluster                2   1
# Behavioural Symptoms
# 0.000000               0   5
# 0.333333               0   8
# 0.500000               0   1
# 0.666667               0   7
# 1.000000               0   7
# 1.333333               1   7
# 1.666667               3  10
# 2.000000               0   7
# 2.333333               8   1
# 2.666667               5   0
# 3.000000              36   0
#
# For the feature Behavioural Symptoms, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Behavioural Symptoms
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are statistically different regarding the feature Behavioural Symptoms.
#
#  Cluster                2   3
# Behavioural Symptoms
# 0.000000               0   2
# 0.333333               0   0
# 0.500000               0   0
# 0.666667               0   0
# 1.000000               0   4
# 1.333333               1  11
# 1.666667               3   6
# 2.000000               0  17
# 2.333333               8   3
# 2.666667               5   5
# 3.000000              36   6
#
# For the feature Behavioural Symptoms, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Behavioural Symptoms
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are statistically different regarding the feature Behavioural Symptoms.
#
#  Cluster                1   3
# Behavioural Symptoms
# 0.000000               5   2
# 0.333333               8   0
# 0.500000               1   0
# 0.666667               7   0
# 1.000000               7   4
# 1.333333               7  11
# 1.666667              10   6
# 2.000000               7  17
# 2.333333               1   3
# 2.666667               0   5
# 3.000000               0   6
#
# For the feature Behavioural Symptoms, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Behavioural Symptoms
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are statistically different regarding the feature Behavioural Symptoms.
#
#  Cluster                   2   1
# Anxiety Personal Impact
# 0.000000                  0   5
# 0.333333                  0   5
# 0.500000                  0   1
# 0.666667                  0   7
# 1.000000                  0  10
# 1.333333                  0   7
# 1.500000                  0   1
# 1.666667                  2   6
# 2.000000                  2   6
# 2.333333                  9   5
# 2.666667                  8   0
# 3.000000                 32   0
#
# For the feature Anxiety Personal Impact, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Anxiety Personal Impact
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are statistically different regarding the feature Anxiety Personal Impact.
#
#  Cluster                   2   3
# Anxiety Personal Impact
# 0.000000                  0   0
# 0.333333                  0   0
# 0.500000                  0   0
# 0.666667                  0   1
# 1.000000                  0   4
# 1.333333                  0   6
# 1.500000                  0   0
# 1.666667                  2   8
# 2.000000                  2  15
# 2.333333                  9  10
# 2.666667                  8   3
# 3.000000                 32   7
#
# For the feature Anxiety Personal Impact, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Anxiety Personal Impact
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are statistically different regarding the feature Anxiety Personal Impact.
#
#  Cluster                   1   3
# Anxiety Personal Impact
# 0.000000                  5   0
# 0.333333                  5   0
# 0.500000                  1   0
# 0.666667                  7   1
# 1.000000                 10   4
# 1.333333                  7   6
# 1.500000                  1   0
# 1.666667                  6   8
# 2.000000                  6  15
# 2.333333                  5  10
# 2.666667                  0   3
# 3.000000                  0   7
#
# For the feature Anxiety Personal Impact, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Anxiety Personal Impact
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are statistically different regarding the feature Anxiety Personal Impact.
#
#  Cluster                  2   1
# Attribution Skepticism
# 0.000000                 0   6
# 0.333333                 0  12
# 0.666667                 0  12
# 1.000000                 0  14
# 1.333333                 0   8
# 1.666667                 0   1
# 2.000000                 0   0
# 2.333333                 0   0
# 2.500000                 1   0
# 2.666667                 0   0
# 3.000000                18   0
# 3.333333                11   0
# 3.666667                 9   0
# 4.000000                14   0
#
# For the feature Attribution Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Attribution Skepticism
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are statistically different regarding the feature Attribution Skepticism.
#
#  Cluster                  2   3
# Attribution Skepticism
# 0.000000                 0   0
# 0.333333                 0   0
# 0.666667                 0   0
# 1.000000                 0   0
# 1.333333                 0   0
# 1.666667                 0  14
# 2.000000                 0   8
# 2.333333                 0  14
# 2.500000                 1   1
# 2.666667                 0  17
# 3.000000                18   0
# 3.333333                11   0
# 3.666667                 9   0
# 4.000000                14   0
#
# For the feature Attribution Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Attribution Skepticism
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are statistically different regarding the feature Attribution Skepticism.
#
#  Cluster                  1   3
# Attribution Skepticism
# 0.000000                 6   0
# 0.333333                12   0
# 0.666667                12   0
# 1.000000                14   0
# 1.333333                 8   0
# 1.666667                 1  14
# 2.000000                 0   8
# 2.333333                 0  14
# 2.500000                 0   1
# 2.666667                 0  17
# 3.000000                 0   0
# 3.333333                 0   0
# 3.666667                 0   0
# 4.000000                 0   0
#
# For the feature Attribution Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Attribution Skepticism
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are statistically different regarding the feature Attribution Skepticism.
#
#  Cluster             2   1
# Impact Skepticism
# 0.000000            0  10
# 0.333333            0  14
# 0.500000            0   0
# 0.666667            0   7
# 1.000000            0  12
# 1.333333            0  10
# 3.000000           21   0
# 3.333333           15   0
# 3.666667            4   0
# 4.000000           12   0
# 5.000000            1   0
#
# For the feature Impact Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Impact Skepticism
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are statistically different regarding the feature Impact Skepticism.
#
#  Cluster             2   3
# Impact Skepticism
# 0.000000            0  10
# 0.333333            0  16
# 0.500000            0   1
# 0.666667            0  12
# 1.000000            0   4
# 1.333333            0  11
# 3.000000           21   0
# 3.333333           15   0
# 3.666667            4   0
# 4.000000           12   0
# 5.000000            1   0
#
# For the feature Impact Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Impact Skepticism
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are statistically different regarding the feature Impact Skepticism.
#
#  Cluster             1   3
# Impact Skepticism
# 0.000000           10  10
# 0.333333           14  16
# 0.500000            0   1
# 0.666667            7  12
# 1.000000           12   4
# 1.333333           10  11
# 3.000000            0   0
# 3.333333            0   0
# 3.666667            0   0
# 4.000000            0   0
# 5.000000            0   0
#
# For the feature Impact Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Impact Skepticism
# Fisher P value: 0.2618691
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are NOT statistically different regarding the feature Impact Skepticism.
#
#  Cluster            2   1
# Trend Skepticism
# 0.000000           0   8
# 0.333333           0   5
# 0.500000           0   1
# 0.666667           0   9
# 1.000000           0  13
# 1.333333           0  16
# 1.666667           0   1
# 2.000000           0   0
# 2.333333           0   0
# 2.666667           0   0
# 3.000000          12   0
# 3.333333          16   0
# 3.666667           9   0
# 4.000000          15   0
# 5.000000           1   0
#
# For the feature Trend Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Trend Skepticism
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are statistically different regarding the feature Trend Skepticism.
#
#  Cluster            2   3
# Trend Skepticism
# 0.000000           0   0
# 0.333333           0   0
# 0.500000           0   0
# 0.666667           0   0
# 1.000000           0   0
# 1.333333           0   0
# 1.666667           0  14
# 2.000000           0  18
# 2.333333           0  13
# 2.666667           0   9
# 3.000000          12   0
# 3.333333          16   0
# 3.666667           9   0
# 4.000000          15   0
# 5.000000           1   0
#
# For the feature Trend Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Trend Skepticism
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are statistically different regarding the feature Trend Skepticism.
#
#  Cluster            1   3
# Trend Skepticism
# 0.000000           8   0
# 0.333333           5   0
# 0.500000           1   0
# 0.666667           9   0
# 1.000000          13   0
# 1.333333          16   0
# 1.666667           1  14
# 2.000000           0  18
# 2.333333           0  13
# 2.666667           0   9
# 3.000000           0   0
# 3.333333           0   0
# 3.666667           0   0
# 4.000000           0   0
# 5.000000           0   0
#
# For the feature Trend Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Trend Skepticism
# Fisher P value: 0.0004997501
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are statistically different regarding the feature Trend Skepticism.
#
#  Cluster               2   1
# Response Skepticism
# 0.000000              0   0
# 0.500000              1   0
# 1.666667             16  13
# 2.000000             11  12
# 2.333333             16  13
# 2.666667              9  14
# 3.000000              0   1
#
# For the feature Response Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Response Skepticism
# Fisher P value: 0.6311844
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are NOT statistically different regarding the feature Response Skepticism.
#
#  Cluster               2   3
# Response Skepticism
# 0.000000              0   1
# 0.500000              1   0
# 1.666667             16  15
# 2.000000             11  11
# 2.333333             16  15
# 2.666667              9  12
# 3.000000              0   0
#
# For the feature Response Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Response Skepticism
# Fisher P value: 0.934033
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are NOT statistically different regarding the feature Response Skepticism.
#
#  Cluster               1   3
# Response Skepticism
# 0.000000              0   1
# 0.500000              0   0
# 1.666667             13  15
# 2.000000             12  11
# 2.333333             13  15
# 2.666667             14  12
# 3.000000              1   0
#
# For the feature Response Skepticism, some expected frequencies are below 5. Consider alternative methods.
# I have to perform Fisher's Exact Test for non binary features.
# Feature: Response Skepticism
# Fisher P value: 0.941029
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are NOT statistically different regarding the feature Response Skepticism.
#
#  Cluster   2   1
# Male
# False    44  42
# True      9  11
#
# For the feature Male, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Male, Cluster Pair: 2 vs 1
# Chi-square Statistic: 0.06162790697674419
# P-Value: 0.8039412247829304
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are NOT statistically different regarding the feature Male.
#
#  Cluster   2   3
# Male
# False    44  38
# True      9  16
#
# For the feature Male, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Male, Cluster Pair: 2 vs 3
# Chi-square Statistic: 1.7356838557379293
# P-Value: 0.1876866412970628
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are NOT statistically different regarding the feature Male.
#
#  Cluster   1   3
# Male
# False    42  38
# True     11  16
#
# For the feature Male, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Male, Cluster Pair: 1 vs 3
# Chi-square Statistic: 0.6958075727282136
# P-Value: 0.40419600654643784
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are NOT statistically different regarding the feature Male.
#
#  Cluster   2   1
# Female
# False    36  37
# True     17  16
#
# For the feature Female, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Female, Cluster Pair: 2 vs 1
# Chi-square Statistic: 0.0
# P-Value: 1.0
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are NOT statistically different regarding the feature Female.
#
#  Cluster   2   3
# Female
# False    36  47
# True     17   7
#
# For the feature Female, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Female, Cluster Pair: 2 vs 3
# Chi-square Statistic: 4.570872720441515
# P-Value: 0.03251999441426126
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are NOT statistically different regarding the feature Female.
#
#  Cluster   1   3
# Female
# False    37  47
# True     16   7
#
# For the feature Female, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Female, Cluster Pair: 1 vs 3
# Chi-square Statistic: 3.737875096032397
# P-Value: 0.05319204965179591
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are NOT statistically different regarding the feature Female.
#
#  Cluster      2   1
# Non-binary
# False       42  42
# True        11  11
#
# For the feature Non-binary, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Non-binary, Cluster Pair: 2 vs 1
# Chi-square Statistic: 0.0
# P-Value: 1.0
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are NOT statistically different regarding the feature Non-binary.
#
#  Cluster      2   3
# Non-binary
# False       42  39
# True        11  15
#
# For the feature Non-binary, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Non-binary, Cluster Pair: 2 vs 3
# Chi-square Statistic: 0.38622450215450443
# P-Value: 0.5342906701040515
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are NOT statistically different regarding the feature Non-binary.
#
#  Cluster      1   3
# Non-binary
# False       42  39
# True        11  15
#
# For the feature Non-binary, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Non-binary, Cluster Pair: 1 vs 3
# Chi-square Statistic: 0.38622450215450443
# P-Value: 0.5342906701040515
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are NOT statistically different regarding the feature Non-binary.
#
#  Cluster   2   1
# Single
# False    53  25
# True      0  28
#
# For the feature Single, some expected frequencies are below 5. Consider alternative methods.
# I can perform Fisher's Exact Test.
# Feature: Single
# Fisher Odds Ratio: inf, p-value: 5.445381283046879e-11
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are statistically different regarding the feature Single.
#
#  Cluster   2   3
# Single
# False    53  49
# True      0   5
#
# For the feature Single, some expected frequencies are below 5. Consider alternative methods.
# I can perform Fisher's Exact Test.
# Feature: Single
# Fisher Odds Ratio: inf, p-value: 0.056742323097463285
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are NOT statistically different regarding the feature Single.
#
#  Cluster   1   3
# Single
# False    25  49
# True     28   5
#
# For the feature Single, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Single, Cluster Pair: 1 vs 3
# Chi-square Statistic: 21.807874305122734
# P-Value: 3.0136079466211785e-06
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are statistically different regarding the feature Single.
#
#  Cluster   2   1
# Married
# False    28  41
# True     25  12
#
# For the feature Married, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Married, Cluster Pair: 2 vs 1
# Chi-square Statistic: 5.978848413631022
# P-Value: 0.01447845284719419
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are statistically different regarding the feature Married.
#
#  Cluster   2   3
# Married
# False    28  19
# True     25  35
#
# For the feature Married, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Married, Cluster Pair: 2 vs 3
# Chi-square Statistic: 2.702592388152905
# P-Value: 0.1001852249038985
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are NOT statistically different regarding the feature Married.
#
#  Cluster   1   3
# Married
# False    41  19
# True     12  35
#
# For the feature Married, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Married, Cluster Pair: 1 vs 3
# Chi-square Statistic: 17.640067297827738
# P-Value: 2.6690553586598522e-05
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are statistically different regarding the feature Married.
#
#  Cluster    2   1
# Divorced
# False     40  46
# True      13   7
#
# For the feature Divorced, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Divorced, Cluster Pair: 2 vs 1
# Chi-square Statistic: 1.5406976744186047
# P-Value: 0.2145139875972429
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are NOT statistically different regarding the feature Divorced.
#
#  Cluster    2   3
# Divorced
# False     40  48
# True      13   6
#
# For the feature Divorced, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Divorced, Cluster Pair: 2 vs 3
# Chi-square Statistic: 2.442422560176409
# P-Value: 0.11809371860661008
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are NOT statistically different regarding the feature Divorced.
#
#  Cluster    1   3
# Divorced
# False     46  48
# True       7   6
#
# For the feature Divorced, all expected frequencies are at least 5. I can perform Chi-Squared test
# Feature: Divorced, Cluster Pair: 1 vs 3
# Chi-square Statistic: 0.0012926163819379326
# P-Value: 0.9713198555294354
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are NOT statistically different regarding the feature Divorced.
#
#  Cluster   2   1
# Widowed
# False    49  53
# True      4   0
#
# For the feature Widowed, some expected frequencies are below 5. Consider alternative methods.
# I can perform Fisher's Exact Test.
# Feature: Widowed
# Fisher Odds Ratio: 0.0, p-value: 0.11789181692094317
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are NOT statistically different regarding the feature Widowed.
#
#  Cluster   2   3
# Widowed
# False    49  50
# True      4   4
#
# For the feature Widowed, some expected frequencies are below 5. Consider alternative methods.
# I can perform Fisher's Exact Test.
# Feature: Widowed
# Fisher Odds Ratio: 0.98, p-value: 1.0
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are NOT statistically different regarding the feature Widowed.
#
#  Cluster   1   3
# Widowed
# False    53  50
# True      0   4
#
# For the feature Widowed, some expected frequencies are below 5. Consider alternative methods.
# I can perform Fisher's Exact Test.
# Feature: Widowed
# Fisher Odds Ratio: inf, p-value: 0.1180240320427236
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are NOT statistically different regarding the feature Widowed.
#
#  Cluster     2   1
# Separated
# False      44  53
# True        9   0
#
# For the feature Separated, some expected frequencies are below 5. Consider alternative methods.
# I can perform Fisher's Exact Test.
# Feature: Separated
# Fisher Odds Ratio: 0.0, p-value: 0.0026990216358667766
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 1 are statistically different regarding the feature Separated.
#
#  Cluster     2   3
# Separated
# False      44  54
# True        9   0
#
# For the feature Separated, some expected frequencies are below 5. Consider alternative methods.
# I can perform Fisher's Exact Test.
# Feature: Separated
# Fisher Odds Ratio: 0.0, p-value: 0.0012360005622193647
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 2 and 3 are statistically different regarding the feature Separated.
#
#  Cluster     1   3
# Separated
# False      53  54
# True        0   0
#
# For the feature Separated, some expected frequencies are below 5. Consider alternative methods.
# I can perform Fisher's Exact Test.
# Feature: Separated
# Fisher Odds Ratio: nan, p-value: 1.0
# Adjusted alpha with Bonferroni: 0.016666666666666666
# The clusters 1 and 3 are NOT statistically different regarding the feature Separated.

# %%
for variable, count in count_dict.items():
    print(f"Number of p-values > 0.0167 for {variable}: {count}")
# Out:
# Number of p-values > 0.0167 for Education: 0
# Number of p-values > 0.0167 for Affective Symptoms: 0
# Number of p-values > 0.0167 for Rumination: 0
# Number of p-values > 0.0167 for Behavioural Symptoms: 0
# Number of p-values > 0.0167 for Anxiety Personal Impact: 0
# Number of p-values > 0.0167 for Attribution Skepticism: 0
# Number of p-values > 0.0167 for Impact Skepticism: 1
# Number of p-values > 0.0167 for Trend Skepticism: 0
# Number of p-values > 0.0167 for Response Skepticism: 3
# Number of p-values > 0.0167 for Male: 3
# Number of p-values > 0.0167 for Female: 3
# Number of p-values > 0.0167 for Non-binary: 3
# Number of p-values > 0.0167 for Single: 1
# Number of p-values > 0.0167 for Married: 1
# Number of p-values > 0.0167 for Divorced: 3
# Number of p-values > 0.0167 for Widowed: 3
# Number of p-values > 0.0167 for Separated: 1
# Number of p-values > 0.0167 for Cluster: 0

# %% [markdown]
# ##  NUMERICAL VARIABLES (Kruskal-Wallis Test + Pairwise MannWhitney U Tests)

# %%
df_numerical = data
columns_to_drop = ['Education', 'Affective Symptoms', 'Rumination', 'Behavioural Symptoms','Anxiety Personal Impact', 'Attribution Skepticism', 'Impact Skepticism', 'Trend Skepticism', 'Response Skepticism', 'Male',
       'Female', 'Non-binary', 'Single', 'Married', 'Divorced', 'Widowed',
       'Separated']
#columns_to_drop = ['Cluster']
df_numerical = df_numerical.drop(columns=columns_to_drop)
print(df_numerical.columns)
# Out:
# Index(['Age', 'Income', 'Cluster'], dtype='object')

# %%
alpha_corrected = 0.05 / 3
# Calculate the Kruskal-Wallis test for each column with respect to the groups defined by 'Clusters'.
columns_to_test = ['Age', 'Income']
for column in columns_to_test:
    groups = [df_numerical[column][df_numerical['Cluster'] == i] for i in range(1, 4)]
    kruskal_stat, kruskal_p_value = kruskal(*groups)
    print(f"Kruskal-Wallis Test for {column}: Statistic = {kruskal_stat}, p-value = {kruskal_p_value}")

    # If the p-value of the Kruskal-Wallis test is significant, perform Mann-Whitney U pairwise tests
    if kruskal_p_value < 0.05:
        pairwise_combs = list(combinations(range(1, 4), 2))
        for comb in pairwise_combs:
            group1 = groups[comb[0] - 1]
            group2 = groups[comb[1] - 1]
            mannwhitneyu_stat, mannwhitneyu_p_value = mannwhitneyu(group1, group2)
            # Comparison with Bonferroni's corrected threshold
            if mannwhitneyu_p_value < alpha_corrected:
                print(f"Mann-Whitney U Test between cluster {comb[0]} and cluster {comb[1]} for {column}: "
                      f"Statistic = {mannwhitneyu_stat}, p-value = {mannwhitneyu_p_value} (Statistical difference)")
            else:
                print(f"Mann-Whitney U Test between cluster {comb[0]} and cluster {comb[1]} for {column}: "
                      f"Statistic = {mannwhitneyu_stat}, p-value = {mannwhitneyu_p_value} (No statistical difference)")
# Out:
# Kruskal-Wallis Test for Age: Statistic = 104.89273324283666, p-value = 1.6704457674798354e-23
# Mann-Whitney U Test between cluster 1 and cluster 2 for Age: Statistic = 7.0, p-value = 1.01518886253871e-18 (Statistical difference)
# Mann-Whitney U Test between cluster 1 and cluster 3 for Age: Statistic = 10.0, p-value = 8.07241154519579e-19 (Statistical difference)
# Mann-Whitney U Test between cluster 2 and cluster 3 for Age: Statistic = 1560.5, p-value = 0.42033942889913023 (No statistical difference)
# Kruskal-Wallis Test for Income: Statistic = 84.69148565333114, p-value = 4.0689050762271256e-19
# Mann-Whitney U Test between cluster 1 and cluster 2 for Income: Statistic = 2652.5, p-value = 3.0953455055822063e-15 (Statistical difference)
# Mann-Whitney U Test between cluster 1 and cluster 3 for Income: Statistic = 1312.0, p-value = 0.45951130427912523 (No statistical difference)
# Mann-Whitney U Test between cluster 2 and cluster 3 for Income: Statistic = 146.5, p-value = 1.1825570172755493e-15 (Statistical difference)

# %% [markdown]
# # Table creation

# %% [markdown]
# ### Tendencies

# %%
group_1 = data.loc[(data['Cluster']==1), :] 
group_2 = data.loc[(data['Cluster']==2), :] 
group_3 = data.loc[(data['Cluster']==3), :] 

# print(group_1)
print('The number of pp in group 1 is: ' , len(group_1))
# print(group_2)
print('The number of pp in group 2 is: ' , len(group_2))
# print(group_3)
print('The number of pp in group 3 is: ' , len(group_3))
# Out:
# The number of pp in group 1 is:  53
# The number of pp in group 2 is:  53
# The number of pp in group 3 is:  54

# %% [markdown]
# Group 1

# %%
column_means_1 = group_1.mean()
column_modes_1 = group_1.mode()
column_medians_1 = group_1.median()

print(column_means_1)
print(column_modes_1)
print(column_medians_1)
# Out:
# Age                           26.188679
# Education                     19.077370
# Affective Symptoms             1.036164
# Rumination                     1.037736
# Behavioural Symptoms           1.078616
# Anxiety Personal Impact        1.157233
# Attribution Skepticism         0.723270
# Impact Skepticism              0.654088
# Trend Skepticism               0.833333
# Response Skepticism            2.194969
# Male                           0.207547
# Female                         0.301887
# Non-binary                     0.207547
# Single                         0.528302
# Married                        0.226415
# Divorced                       0.132075
# Widowed                        0.000000
# Separated                      0.000000
# Income                     33211.320755
# Cluster                        1.000000
# dtype: float64
#     Age  Education  Affective Symptoms  Rumination  Behavioural Symptoms  \
# 0  19.0       18.0                0.75    0.333333              1.666667
# 1   NaN        NaN                 NaN    1.333333                   NaN
#
#    Anxiety Personal Impact  Attribution Skepticism  Impact Skepticism  \
# 0                      1.0                     1.0           0.333333
# 1                      NaN                     NaN                NaN
#
#    Trend Skepticism  Response Skepticism   Male Female Non-binary Single  \
# 0          1.333333             2.666667  False  False      False   True
# 1               NaN                  NaN    NaN    NaN        NaN    NaN
#
#   Married Divorced Widowed Separated   Income  Cluster
# 0   False    False   False     False  33000.0      1.0
# 1     NaN      NaN     NaN       NaN      NaN      NaN
# Age                           27.000000
# Education                     18.000000
# Affective Symptoms             1.000000
# Rumination                     1.000000
# Behavioural Symptoms           1.000000
# Anxiety Personal Impact        1.000000
# Attribution Skepticism         0.666667
# Impact Skepticism              0.666667
# Trend Skepticism               1.000000
# Response Skepticism            2.333333
# Male                           0.000000
# Female                         0.000000
# Non-binary                     0.000000
# Single                         1.000000
# Married                        0.000000
# Divorced                       0.000000
# Widowed                        0.000000
# Separated                      0.000000
# Income                     33000.000000
# Cluster                        1.000000
# dtype: float64

# %% [markdown]
# Group 2

# %%
column_means_2 = group_2.mean()
column_modes_2 = group_2.mode()
column_medians_2 = group_2.median()

print(column_means_2)
print(column_modes_2)
print(column_medians_2)
# Out:
# Age                           45.641509
# Education                     10.188679
# Affective Symptoms             2.721698
# Rumination                     2.710692
# Behavioural Symptoms           2.761006
# Anxiety Personal Impact        2.748428
# Attribution Skepticism         3.437107
# Impact Skepticism              3.408805
# Trend Skepticism               3.534591
# Response Skepticism            2.084906
# Male                           0.169811
# Female                         0.320755
# Non-binary                     0.207547
# Single                         0.000000
# Married                        0.471698
# Divorced                       0.245283
# Widowed                        0.075472
# Separated                      0.169811
# Income                     19682.943396
# Cluster                        2.000000
# dtype: float64
#     Age  Education  Affective Symptoms  Rumination  Behavioural Symptoms  \
# 0  42.0        8.0                 3.0         3.0                   3.0
# 1  53.0        NaN                 NaN         NaN                   NaN
#
#    Anxiety Personal Impact  Attribution Skepticism  Impact Skepticism  \
# 0                      3.0                     3.0                3.0
# 1                      NaN                     NaN                NaN
#
#    Trend Skepticism  Response Skepticism   Male Female Non-binary Single  \
# 0          3.333333             1.666667  False  False      False  False
# 1               NaN             2.333333    NaN    NaN        NaN    NaN
#
#   Married Divorced Widowed Separated   Income  Cluster
# 0   False    False   False     False  21000.0      2.0
# 1     NaN      NaN     NaN       NaN      NaN      NaN
# Age                           45.000000
# Education                      8.000000
# Affective Symptoms             2.750000
# Rumination                     3.000000
# Behavioural Symptoms           3.000000
# Anxiety Personal Impact        3.000000
# Attribution Skepticism         3.333333
# Impact Skepticism              3.333333
# Trend Skepticism               3.333333
# Response Skepticism            2.000000
# Male                           0.000000
# Female                         0.000000
# Non-binary                     0.000000
# Single                         0.000000
# Married                        0.000000
# Divorced                       0.000000
# Widowed                        0.000000
# Separated                      0.000000
# Income                     20000.000000
# Cluster                        2.000000
# dtype: float64

# %% [markdown]
# Group 3

# %%
column_means_3 = group_3.mean()
column_modes_3 = group_3.mode()
column_medians_3 = group_3.median()

print(column_means_3)
print(column_modes_3)
print(column_medians_3)
# Out:
# Age                           44.831936
# Education                     13.055556
# Affective Symptoms             1.939815
# Rumination                     2.030864
# Behavioural Symptoms           1.870370
# Anxiety Personal Impact        2.006173
# Attribution Skepticism         2.219136
# Impact Skepticism              0.601852
# Trend Skepticism               2.104938
# Response Skepticism            2.111111
# Male                           0.296296
# Female                         0.129630
# Non-binary                     0.277778
# Single                         0.092593
# Married                        0.648148
# Divorced                       0.111111
# Widowed                        0.074074
# Separated                      0.000000
# Income                     34533.333333
# Cluster                        3.000000
# dtype: float64
#     Age  Education  Affective Symptoms  Rumination  Behavioural Symptoms  \
# 0  42.0       13.0                 2.0         2.0                   2.0
# 1   NaN        NaN                 NaN         NaN                   NaN
#
#    Anxiety Personal Impact  Attribution Skepticism  Impact Skepticism  \
# 0                      2.0                2.666667           0.333333
# 1                      NaN                     NaN                NaN
#
#    Trend Skepticism  Response Skepticism   Male Female Non-binary Single  \
# 0               2.0             1.666667  False  False      False  False
# 1               NaN             2.333333    NaN    NaN        NaN    NaN
#
#   Married Divorced Widowed Separated  Income  Cluster
# 0    True    False   False     False   29000      3.0
# 1     NaN      NaN     NaN       NaN   40000      NaN
# Age                           45.000000
# Education                     13.000000
# Affective Symptoms             2.000000
# Rumination                     2.000000
# Behavioural Symptoms           2.000000
# Anxiety Personal Impact        2.000000
# Attribution Skepticism         2.333333
# Impact Skepticism              0.583333
# Trend Skepticism               2.000000
# Response Skepticism            2.166667
# Male                           0.000000
# Female                         0.000000
# Non-binary                     0.000000
# Single                         0.000000
# Married                        1.000000
# Divorced                       0.000000
# Widowed                        0.000000
# Separated                      0.000000
# Income                     33000.000000
# Cluster                        3.000000
# dtype: float64

# %% [markdown]
# I decided to take the modes as the values to put in the table

# %%
group_1_tendency = column_modes_1.iloc[0]
print('Group 1 Central Tendency is:\n', group_1_tendency, '\n')

group_2_tendency = column_modes_2.iloc[0]
print('Group 2 Central Tendency is:\n', group_2_tendency, '\n')

group_3_tendency = column_modes_3.iloc[0]
print('Group 3 Central Tendency is:\n', group_3_tendency, '\n')
# Out:
# Group 1 Central Tendency is:
#  Age                            19.0
# Education                      18.0
# Affective Symptoms             0.75
# Rumination                 0.333333
# Behavioural Symptoms       1.666667
# Anxiety Personal Impact         1.0
# Attribution Skepticism          1.0
# Impact Skepticism          0.333333
# Trend Skepticism           1.333333
# Response Skepticism        2.666667
# Male                          False
# Female                        False
# Non-binary                    False
# Single                         True
# Married                       False
# Divorced                      False
# Widowed                       False
# Separated                     False
# Income                      33000.0
# Cluster                         1.0
# Name: 0, dtype: object
#
# Group 2 Central Tendency is:
#  Age                            42.0
# Education                       8.0
# Affective Symptoms              3.0
# Rumination                      3.0
# Behavioural Symptoms            3.0
# Anxiety Personal Impact         3.0
# Attribution Skepticism          3.0
# Impact Skepticism               3.0
# Trend Skepticism           3.333333
# Response Skepticism        1.666667
# Male                          False
# Female                        False
# Non-binary                    False
# Single                        False
# Married                       False
# Divorced                      False
# Widowed                       False
# Separated                     False
# Income                      21000.0
# Cluster                         2.0
# Name: 0, dtype: object
#
# Group 3 Central Tendency is:
#  Age                            42.0
# Education                      13.0
# Affective Symptoms              2.0
# Rumination                      2.0
# Behavioural Symptoms            2.0
# Anxiety Personal Impact         2.0
# Attribution Skepticism     2.666667
# Impact Skepticism          0.333333
# Trend Skepticism                2.0
# Response Skepticism        1.666667
# Male                          False
# Female                        False
# Non-binary                    False
# Single                        False
# Married                        True
# Divorced                      False
# Widowed                       False
# Separated                     False
# Income                        29000
# Cluster                         3.0
# Name: 0, dtype: object

# %% [markdown]
# ### Computation of  Percentages

# %%
indexes_list = group_1_tendency.index.tolist()

# Calculate the frequency of the mode 1
percentage_occurrence_1 = group_1_tendency.copy()

for attribute in indexes_list:
    mode_value_1 = group_1_tendency[attribute]
    mode_frequency_1 = (group_1[attribute] == mode_value_1).sum()

    percentage_occurrence_1[attribute] = mode_frequency_1 / len(group_1) * 100

print('Percentages of Group 1: \n' , percentage_occurrence_1, '\n')

# Calculate the frequency of the mode 2
percentage_occurrence_2 = group_2_tendency.copy()
 
for attribute in indexes_list:
    mode_value_2 = group_2_tendency[attribute]
    mode_frequency_2 = (group_2[attribute] == mode_value_2).sum()

    percentage_occurrence_2[attribute] = mode_frequency_2 / len(group_2) * 100

print('Percentages of Group 2: \n' , percentage_occurrence_2, '\n')

# Calculate the frequency of the mode 3
percentage_occurrence_3 = group_3_tendency.copy()
 
for attribute in indexes_list:
    mode_value_3 = group_3_tendency[attribute]
    mode_frequency_3 = (group_3[attribute] == mode_value_3).sum()

    percentage_occurrence_3[attribute] = mode_frequency_3 / len(group_3) * 100

print('Percentages of Group 3: \n' , percentage_occurrence_3, '\n')
# Out:
# Percentages of Group 1:
#  Age                        13.207547
# Education                  33.962264
# Affective Symptoms         20.754717
# Rumination                 16.981132
# Behavioural Symptoms       18.867925
# Anxiety Personal Impact    18.867925
# Attribution Skepticism     26.415094
# Impact Skepticism          26.415094
# Trend Skepticism           30.188679
# Response Skepticism        26.415094
# Male                       79.245283
# Female                     69.811321
# Non-binary                 79.245283
# Single                     52.830189
# Married                    77.358491
# Divorced                   86.792453
# Widowed                        100.0
# Separated                      100.0
# Income                     11.320755
# Cluster                        100.0
# Name: 0, dtype: object
#
# Percentages of Group 2:
#  Age                        11.320755
# Education                  45.283019
# Affective Symptoms         43.396226
# Rumination                 50.943396
# Behavioural Symptoms       67.924528
# Anxiety Personal Impact    60.377358
# Attribution Skepticism     33.962264
# Impact Skepticism          39.622642
# Trend Skepticism           30.188679
# Response Skepticism        30.188679
# Male                       83.018868
# Female                     67.924528
# Non-binary                 79.245283
# Single                         100.0
# Married                    52.830189
# Divorced                   75.471698
# Widowed                     92.45283
# Separated                  83.018868
# Income                      9.433962
# Cluster                        100.0
# Name: 0, dtype: object
#
# Percentages of Group 3:
#  Age                        14.814815
# Education                  57.407407
# Affective Symptoms         18.518519
# Rumination                  29.62963
# Behavioural Symptoms       31.481481
# Anxiety Personal Impact    27.777778
# Attribution Skepticism     31.481481
# Impact Skepticism           29.62963
# Trend Skepticism           33.333333
# Response Skepticism        27.777778
# Male                        70.37037
# Female                     87.037037
# Non-binary                 72.222222
# Single                     90.740741
# Married                    64.814815
# Divorced                   88.888889
# Widowed                    92.592593
# Separated                      100.0
# Income                     11.111111
# Cluster                        100.0
# Name: 0, dtype: object

# %% [markdown]
# ### Final table

# %%
indexes_list = group_1_tendency.index.tolist()
res = {'': indexes_list, 'Group 1': group_1_tendency, '% 1': percentage_occurrence_1, 'Group 2': group_2_tendency, 
'% 2': percentage_occurrence_2, 'Group 3': group_3_tendency, '% 3': percentage_occurrence_3}
tabella = pd.DataFrame(res)
tabella_arrotondata = tabella.round(1)
tabella_arrotondata = tabella_arrotondata.drop(tabella_arrotondata.index[-1]) # tolgo la riga Cluster

print(tabella_arrotondata)
# tabella_arrotondata.to_csv('tabella gruppi (cvs).csv', index=False)
# Out:
#                                                    Group 1        % 1  \
# Age                                          Age      19.0  13.207547
# Education                              Education      18.0  33.962264
# Affective Symptoms            Affective Symptoms      0.75  20.754717
# Rumination                            Rumination  0.333333  16.981132
# Behavioural Symptoms        Behavioural Symptoms  1.666667  18.867925
# Anxiety Personal Impact  Anxiety Personal Impact       1.0  18.867925
# Attribution Skepticism    Attribution Skepticism       1.0  26.415094
# Impact Skepticism              Impact Skepticism  0.333333  26.415094
# Trend Skepticism                Trend Skepticism  1.333333  30.188679
# Response Skepticism          Response Skepticism  2.666667  26.415094
# Male                                        Male     False  79.245283
# Female                                    Female     False  69.811321
# Non-binary                            Non-binary     False  79.245283
# Single                                    Single      True  52.830189
# Married                                  Married     False  77.358491
# Divorced                                Divorced     False  86.792453
# Widowed                                  Widowed     False      100.0
# Separated                              Separated     False      100.0
# Income                                    Income   33000.0  11.320755
#
#                           Group 2        % 2   Group 3        % 3
# Age                          42.0  11.320755      42.0  14.814815
# Education                     8.0  45.283019      13.0  57.407407
# Affective Symptoms            3.0  43.396226       2.0  18.518519
# Rumination                    3.0  50.943396       2.0   29.62963
# Behavioural Symptoms          3.0  67.924528       2.0  31.481481
# Anxiety Personal Impact       3.0  60.377358       2.0  27.777778
# Attribution Skepticism        3.0  33.962264  2.666667  31.481481
# Impact Skepticism             3.0  39.622642  0.333333   29.62963
# Trend Skepticism         3.333333  30.188679       2.0  33.333333
# Response Skepticism      1.666667  30.188679  1.666667  27.777778
# Male                        False  83.018868     False   70.37037
# Female                      False  67.924528     False  87.037037
# Non-binary                  False  79.245283     False  72.222222
# Single                      False      100.0     False  90.740741
# Married                     False  52.830189      True  64.814815
# Divorced                    False  75.471698     False  88.888889
# Widowed                     False   92.45283     False  92.592593
# Separated                   False  83.018868     False      100.0
# Income                    21000.0   9.433962     29000  11.111111

# %%
column_means_1 = group_1.mean()
column_modes_1 = group_1.mode()
column_medians_1 = group_1.median()

print(column_means_1)
print(column_modes_1)
print(column_medians_1)
# Out:
# Age                           26.188679
# Education                     19.077370
# Affective Symptoms             1.036164
# Rumination                     1.037736
# Behavioural Symptoms           1.078616
# Anxiety Personal Impact        1.157233
# Attribution Skepticism         0.723270
# Impact Skepticism              0.654088
# Trend Skepticism               0.833333
# Response Skepticism            2.194969
# Male                           0.207547
# Female                         0.301887
# Non-binary                     0.207547
# Single                         0.528302
# Married                        0.226415
# Divorced                       0.132075
# Widowed                        0.000000
# Separated                      0.000000
# Income                     33211.320755
# Cluster                        1.000000
# dtype: float64
#     Age  Education  Affective Symptoms  Rumination  Behavioural Symptoms  \
# 0  19.0       18.0                0.75    0.333333              1.666667
# 1   NaN        NaN                 NaN    1.333333                   NaN
#
#    Anxiety Personal Impact  Attribution Skepticism  Impact Skepticism  \
# 0                      1.0                     1.0           0.333333
# 1                      NaN                     NaN                NaN
#
#    Trend Skepticism  Response Skepticism   Male Female Non-binary Single  \
# 0          1.333333             2.666667  False  False      False   True
# 1               NaN                  NaN    NaN    NaN        NaN    NaN
#
#   Married Divorced Widowed Separated   Income  Cluster
# 0   False    False   False     False  33000.0      1.0
# 1     NaN      NaN     NaN       NaN      NaN      NaN
# Age                           27.000000
# Education                     18.000000
# Affective Symptoms             1.000000
# Rumination                     1.000000
# Behavioural Symptoms           1.000000
# Anxiety Personal Impact        1.000000
# Attribution Skepticism         0.666667
# Impact Skepticism              0.666667
# Trend Skepticism               1.000000
# Response Skepticism            2.333333
# Male                           0.000000
# Female                         0.000000
# Non-binary                     0.000000
# Single                         1.000000
# Married                        0.000000
# Divorced                       0.000000
# Widowed                        0.000000
# Separated                      0.000000
# Income                     33000.000000
# Cluster                        1.000000
# dtype: float64
